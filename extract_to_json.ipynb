# %%
import os
import io

import yaml
import json
from collections import OrderedDict

import boto3
from botocore.exceptions import NoCredentialsError, ClientError

import base64  # Added base64 import
from PIL import Image
import fitz  # PyMuPDF

import pytesseract
from bidi.algorithm import get_display  # For Hebrew RTL text display

from openai import OpenAI
from anthropic import Anthropic

# %%
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: C:\github_repos\BIU_LLM_Project

# %%
def load_config(config_file):
    # Load configuration from the YAML file
    with open(config_file, 'r') as file:
        config = yaml.safe_load(file)
    return config

# %%
def init_aws_client(config):
    """Initialize AWS S3 client"""
    return boto3.client(
        's3',
        aws_access_key_id=config['aws']['aws_access_key_id'],
        aws_secret_access_key=config['aws']['aws_secret_access_key'],
        region_name=config['aws']['region_name']
    )

# %%
def get_s3_public_url(bucket_name, file_key, region):
    """Generate S3 public URL"""
    return f"https://{bucket_name}.s3.{region}.amazonaws.com/{file_key}"

# %%
def ensure_tmp_dir():
    """Create and clean temporary directory"""
    tmp_dir = os.path.join(os.getcwd(), 'tmp')
    if not os.path.exists(tmp_dir):
        os.makedirs(tmp_dir)
    else:
        for filename in os.listdir(tmp_dir):
            file_path = os.path.join(tmp_dir, filename)
            try:
                if os.path.isfile(file_path):
                    os.unlink(file_path)
            except Exception as e:
                print(f'Error deleting {file_path}: {e}')
    return tmp_dir

# %%
def extract_text_from_file(file_path):
    """
    Extract both regular text and text from images in an input file.
    """
    
    # Open the PDF document with PyMuPDF (fitz)
    doc = fitz.open(file_path)
    text_content = []  # List to store extracted text and image placeholders
    
    # Loop through each page in the document
    for page_num in range(len(doc)):
        page = doc[page_num]  # Access a specific page in the PDF
        
        # Extract regular text from the page and add to text content list
        text_content.append(page.get_text())
        
        # Extract all images on the page
        image_list = page.get_images()
        for img_index, img in enumerate(image_list):
            try:
                # Get the image reference number (xref) to retrieve the image data
                xref = img[0]
                base_image = doc.extract_image(xref)  # Extracts image data (binary format)
                image_bytes = base_image["image"]  # Retrieves raw image bytes
                
                # Convert the image bytes to a PIL Image object
                image = Image.open(io.BytesIO(image_bytes))
                
                # Use Tesseract OCR to extract text from the image
                # ocr_text = pytesseract.image_to_string(image)
                ocr_text = pytesseract.image_to_string(image, lang="heb+eng")
                
                # Append the extracted text to the content
                # text_content.append(f"[Image OCR Text {page_num + 1}-{img_index + 1}]:\n{ocr_text}")
                text_content.append(f"\n{ocr_text}")
                
            except Exception as e:
                # Print error message if image extraction or OCR fails
                print(f"Error processing image {img_index} from page {page_num}: {str(e)}")
    
    # Close the document to free up resources
    doc.close()

    # Join all text content (including extracted image text) into a single string for output
    extracted_output = "\n".join(text_content)  # Variable for the final output

    print(f"\n Extracted text and images contetnt \n {extracted_output}")  # Print the final output
    
    return extracted_output

# %%
def init_openai(config):
    """Initialize OpenAI API key from configuration."""
    client = OpenAI(api_key=config['openai']['chat_gpt_key'])
    return client

# %%
def analyze_with_openai_eng_new1(config, client, text):
    """Analyze document content using OpenAI's GPT-4o and return structured JSON data.
    
    Args:
        config (dict): Configuration dictionary containing OpenAI settings
        client: OpenAI client instance
        text (str): Input text to analyze
        
    Returns:
        dict: Structured JSON data containing analyzed course information
    """    
    try:
        # Validate input text as UTF-8
        if not isinstance(text, str):
            raise ValueError("Input text must be a UTF-8 encoded string.")
        text = text.encode('utf-8').decode('utf-8')  # Ensure UTF-8 compliance

        system_prompt = {
            "role": "system",
            "content": """
            You are a text extractor and analyzer top expert.
            The text is a course syllabus document that contains the course information.
            
            Your mission is to extract as much information as you can in the given text, and process it into a JSON format.
            Required JSON structure: {"full_text": "The syllabus complete extracted text after you organize it"}           
               
            HOW TO PROCESS THE FULL TEXT
            1. The text will start after @@@@
            2. Read the text very carefully.
            3. Text may be in (Hebrew, English or mixed).
            4. Preserve all language terms (Hebrew, English, or mixed) in their original language.
            5. DO NOT LIMIT RESPONSE LENGTH. WE NEED ALL AVAILABLE INFORMATION FROM THE SOURCE TEXT.
        
            6. For the full_text field, apply these transformations
               - Add topic sentences to each major section.
               - Add clear section headers in capital letters.
               - Normalize spacing and formatting.
               - End all sentences with proper punctuation.
               - Transform bullet points into complete sentences.
               - Create proper paragraphs from lists.
               - Add contextual transitions between sections.
               - Ensure hierarchical content structure.
               - Preserve important dates, numbers, and contact information.
               - Remove duplicate headers/footers.
               - Remove any text that says: "[Embedded Image ]" or similar.
               - Maintain consistent formatting throughout.

            7. Structure the text in these sections
               - COURSE NAME: extract the Course Name that may be in English or Hebrew, beginning with words like: ["Course", "Workshop", "Track Name", "קורס", "סדנה", "סדנא", "מסלול", "לימודי תעודה"]
               - COURSE OVERVIEW: course overview, or the program description.
               - TARGET AUDIENCE: if there are. If not found, skip this section
               - COURSE LEADERSHIP: Include all lecturers and leaders biography and their descriptions. Note for: Academic Director, Academic Leaders and their roles, Academic Advisors and Lecturers etc. If not found, skip this section.
               - PREREQUISITES: if there are. If not found, skip this section
               - CERTIFICATIONS: Create a comma delimited list for all certifications, awards achievements or recognitions. Look for certification terms like: ["certificates", "Certified", "cc"] if there are.
               - COURSE SCHEDULE: look for start date, end date, duration, academic hours, schedules. Be bullet focused.
               - LEARNING FORMAT: look for things like location, in class, remote or hybrid learning options, laboratories, practicum, staj, etc. - if there are: be bullet focused. If not found, skip this section.
               - TUITION AND FEES: look for registration fees, tuition, parking fees. If there are: be bullet focused. If not found, skip this section
               - COURSE TOPICS: Bring ALL learning topics that are in text. BE EXTREMELY DETAILED. DO NOT OMIT ANYTHING. Organize into topics and their bullets.
               - REGISTRATION AND CONTACT INFORMATION: if there are: be bullet focused. If not found, skip this section
               - INSTITUTIONAL INFORMATION: Focused institutional information. If there are: be focused. If not found, skip this section            

            8. Writing style guidelines
               - Use complete sentences.
               - Add context to technical terms.
               - Maintain consistent tense and voice.
               - Ensure clarity and readability.
               - Preserve all information from the given text.

            9. Formatting requirements
               - Use consistent paragraph spacing.
               - Ensure proper nesting of information.
               - Keep important identifiers (emails, URLs, phone numbers etc.) in their original format.
        
            Text to analyze after this @@@@
            """
        }        
                
        # Send prompt to OpenAI GPT for initial processing
        response = client.chat.completions.create(
            model=config['openai']['gpt_model'],  
            messages=[system_prompt, {"role": "user", "content": text}],
            max_tokens=config['rag']['max_output_tokens_rag'],
            temperature=config['rag']['temperature_rag']
        )
        
        # Extract response text from prompt01
        response_text1 = response.choices[0].message.content.strip()
        response_tokens1 = response.usage.completion_tokens

        print(f"\nLLM response_text1 {response_text1}")
       
        # Extract response JSON text from prompt01
        start = response_text1.find('{')
        end = response_text1.rfind('}') + 1
        
        if start != -1 and end != 0:
            json_str1 = response_text1[start:end]
            initial_data = json.loads(json_str1)          
            initial_data_full_text = initial_data.get("full_text", text)
        else:
            raise ValueError("No JSON found in response")

        # Second prompt for detailed extraction
        system_prompt = {
            "role": "system",
            "content": """           
            You are a text extractor and analyzer top expert.
            Your mission is to extract as much information as you can in the given text process it into a JSON format.
            The text is a course syllabus document that contains the course information.
            
            HOW TO PROCESS THE TEXT
            1. The text will start after @@@@
            2. Read the text very carefully.
            3. Text may be in (Hebrew, English or mixed).
            4. Preserve all language terms (Hebrew, English, or mixed) in their original language.
            5. DO NOT LIMIT RESPONSE LENGTH. WE NEED ALL AVAILABLE INFORMATION FROM THE SOURCE TEXT.
            
            WHAT INFORMATION TO EXTRACT
            1. The complete course name exactly as it appears
            
            2. From COURSE LEADERSHIP section:
               - Create a LIST of ALL instructors, including every teaching staff member mentioned in the text
               - For each instructor in the list, extract:
                 * Full name as written
                 * Their role/position (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך, מנהל אקדמי, מוביל אקדמי)
                 * Professional title (if mentioned)
                 * Any additional description or background information
               - Make sure to capture EVERY instructor mentioned, even if some details are missing
               - List format should handle multiple instructors
            
            3. From the entire text:
               - Create a comprehensive course summary
               - Do not use text from INSTITUTIONAL INFORMATION or motto.
            
            4. Return the information in this exact JSON format:
            {
                "course_name": "Complete course name as extracted",
                "instructors": [
                    {
                        "name": "First instructor name",
                        "role": "Role (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך)",
                        "title": "Professional title if available",
                        "description": "Additional description"
                    }
                    // Continue for all instructors found
                ],
                "summary": "Comprehensive course summary"
            }
    
                Important notes for JSON output:
                1. Use null for missing fields
                2. Use empty array [] if no instructors are found          
                3. Maintain JSON list format even if only one instructor is found
    
            Text to analyze after this @@@@
            """
        }              
        
        # Send prompt02 to OpenAI GPT-4 for detailed extraction
        response = client.chat.completions.create(
            model=config['openai']['gpt_model'],  
            messages=[system_prompt, {"role": "user", "content": text}],            
            max_tokens=config['rag']['max_output_tokens_rag'],
            temperature=config['rag']['temperature_rag']
        )
        
        # Extract response JSON text from prompt02
        response_text2 = response.choices[0].message.content.strip()
        print(f"\nLLM response_text2 {response_text2}")
        
        extract_start = response_text2.find('{')
        extract_end = response_text2.rfind('}') + 1
        
        if extract_start != -1 and extract_end != 0:
            extracted_data = json.loads(response_text2[extract_start:extract_end])
        else:
            extracted_data = {
                "course_name": None,
                "instructors": [],
                "summary": None
            }

        # Create merged JSON output
        merged_json = {
            "course_name": extracted_data.get("course_name"),
            "instructors": extracted_data.get("instructors", []),
            "summary": extracted_data.get("summary"),
            "full_text": initial_data_full_text,
            "full_text_no_tokens": response_tokens1
        }

        # Format merged JSON as a readable string for Hebrew
        readable_json = json.dumps(merged_json, ensure_ascii=False, indent=2)
        
        return readable_json
   
    except (json.JSONDecodeError, ValueError) as e:
        print(f"JSON Parse Error: {str(e)}")
        print(f"LLM Response text: {response_text1 if 'response_text1' in locals() else response_text2}")
        return json.dumps({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0
        }, ensure_ascii=False, indent=2)
         
    except Exception as e:
        print(f"Error analyzing with OpenAI: {str(e)}")        
        return json.dumps({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0
        }, ensure_ascii=False, indent=2)

# %%
def analyze_with_openai_eng(config, client, text):
    """Analyze document content using OpenAI's GPT-4o and return structured JSON data.
    
    Args:
        config (dict): Configuration dictionary containing OpenAI settings
        client: OpenAI client instance
        text (str): Input text to analyze
        
    Returns:
        dict: Structured JSON data containing analyzed course information
    """    
    try:
        # Validate input text as UTF-8
        if not isinstance(text, str):
            raise ValueError("Input text must be a UTF-8 encoded string.")
        text = text.encode('utf-8').decode('utf-8')  # Ensure UTF-8 compliance
       
        system_prompt = {
            "role": "system",
            "content": """
            You are a text extractor and analyzer top expert.
            The text is a course syllabus document that contains the course information.
            
            Your mission is to extract as much information as you can in the given text, and process it into a JSON format.
            Required JSON structure: {"full_text": "The sylabus complete extracted text after you orgenize it"}           
               
            HOW TO PROCESS THE FULL TEXT
            1. The text will start after @@@@
            2. Read the text very carefully.
            3. Text may be in (Hebrew, English or mixed).
            4. Preserve all language terms (Hebrew, English, or mixed) in their original language.
            5. DO NOT LIMIT RESPONSE LENGTH. WE NEED ALL AVAILABLE INFORMATION FROM THE SOURCE TEXT.
        
            6. For the full_text field, apply these transformations
               - Add topic sentences to each major section.
               - Add clear section headers in capital letters.
               - Normalize spacing and formatting.
               - End all sentences with proper punctuation.
               - Transform bullet points into complete sentences.
               - Create proper paragraphs from lists.
               - Add contextual transitions between sections.
               - Ensure hierarchical content structure.
               - Preserve important dates, numbers, and contact information.
               - Remove duplicate headers/footers.
               - Remove any text that says: "[Embedded Image ]" or similar.
               - Maintain consistent formatting throughout.

            7. Structure the text in these sections
               - COURSE NAME: extract the Course Name that may in English or Hebrew, begining with words like: ["Course" , "Workshop" , "Track Name", "קורס" , "סדנה" , "סדנא", "מסלול" , "לימודי תעודה"]
               - COURSE OVERVIEW: course overview, or the program description.
               - TARGET AUDIENCE: if there are.if not found, skip this section
               - COURSE LEADERSHIP: Include all lecturers and leaders biography and their descriptions. Note for: Academic Director, Academic Leaders and their roles, Academic Advisors and Lecturers etc. if not found, skip this section.
               - PREREQUISITES: if there are. if not found, skip this section
               - CERTIFICATIONS: Create a comma delimited list for all certifications, awards acheivments or recognitions. Look for certification terms like: ["certificates" , "Certified" "cc"] if there are.
               - COURSE SCHEDULE: look for start date, end date, duration, accademic hours, schedules. be bullet focused.
               - LEARNING FORMAT: look for things like location, in class, remote or hybrid learning options, laboratories, practicum, staj, etc. - if there are: be bullet focused. if not found, skip this section.
               - TUITION AND FEES: look for registration fees, tuition, parking fess. if there are: be bullet focused. if not found, skip this section
               - COURSE TOPICS: Bring ALL learning topics that in text. BE EXTREAMLY DETAILED. DO NOT OMIT ANYTHING. Orgenize to topics and their bullets.
               - REGISTRATION AND CONTACT INFORMATION: if there are: be bullet focused. if not found, skip this section
               - INSTITUTIONAL INFORMATION: Focused institutional information. if there are: be focused. if not found, skip this section            

            8. Writing style guidelines
               - Use complete sentences.
               - Add context to technical terms.
               - Maintain consistent tense and voice.
               - Ensure clarity and readability.
               - Preserve all information from the given text.

            9. Formatting requirements
               - Use consistent paragraph spacing.
               - Ensure proper nesting of information.
               - Keep important identifiers (emails, URLs, phone numbers etc.) in their original format.
        
            Text to analyze after this @@@@
            """
        }        
                
        # Send prompt to OpenAI GPT for initial processing
        response = client.chat.completions.create(
            model=config['openai']['gpt_model'],  
            messages=[system_prompt, {"role": "user", "content": text}],
            max_tokens=config['rag']['max_output_tokens_rag'],
            temperature=config['rag']['temperature_rag']
        )
        
        # Extract response text from prompt01
        response_text1   = response.choices[0].message.content.strip()
        response_tokens1 = response.usage.completion_tokens

        print (f"\n LLM response_text1 {response_text1}")
       
        # Extract response JSON text from prompt01
        start = response_text1.find('{')
        end = response_text1.rfind('}') + 1
        
        if start != -1 and end != 0:
            json_str1 = response_text1[start:end]
            initial_data = json.loads(json_str1)          
            initial_data_full_text = initial_data.get("full_text", text)
        else:
            raise ValueError("No JSON found in response")

        # Second prompt for detailed extraction
        system_prompt = {
            "role": "system",
            "content": """           
            You are a text extractor and analyzer top expert.
            Your mission is to extract as much information as you can in the given text process it into a JSON format.
            The text is a course syllabus document that contains the course information.
            
            HOW TO PROCESS THE TEXT
            1. The text will start after @@@@
            2. Read the text very carefully.
            3. Text may be in (Hebrew, English or mixed).
            4. Preserve all language terms (Hebrew, English, or mixed) in their original language.
            5. DO NOT LIMIT RESPONSE LENGTH. WE NEED ALL AVAILABLE INFORMATION FROM THE SOURCE TEXT.
            
            WHAT INFORMATION TO EXTRACT
            1. The complete course name exactly as it appears
            
            2. From COURSE LEADERSHIP section:
               - Create a LIST of ALL instructors, including every teaching staff member mentioned in the text
               - For each instructor in the list, extract:
                 * Full name as written
                 * Their role/position (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך, מנהל אקדמי, מוביל אקדמי)
                 * Professional title (if mentioned)
                 * Any additional description or background information
               - Make sure to capture EVERY instructor mentioned, even if some details are missing
               - List format should handle multiple instructors
            
            3. From the entire text:
               - Create a comprehensive course summary
               - Do not use text from INSTITUTIONAL INFORMATION or motto.
            
            4. Return the information in this exact JSON format:
            {
                "course_name": "Complete course name as extracted",
                "instructors": [
                    {
                        "name": "First instructor name",
                        "role": "Role (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך)",
                        "title": "Professional title if available",
                        "description": "Additional description"
                    }
                    // Continue for all instructors found
                ],
                "summary": "Comprehensive course summary"
            }
    
                Important notes for JSON output:
                1. Use null for missing fields
                2. Use empty array [] if no instructors are found          
                3. Maintain JSON list format even if only one instructor is found
    
            Text to analyze after this @@@@
            """
        }              
        
        # Send prompt02 to OpenAI GPT-4 for detailed extraction
        response = client.chat.completions.create(
            model=config['openai']['gpt_model'],  
            messages=[system_prompt, {"role": "user", "content": text}],            
            max_tokens=config['rag']['max_output_tokens_rag'],
            temperature=config['rag']['temperature_rag']
        )
        
        # Extract response JSON text from prompt02
        response_text2 = response.choices[0].message.content.strip()
        print (f"\n LLM response_text2 {response_text2}")
        
        extract_start = response_text2.find('{')
        extract_end = response_text2.rfind('}') + 1
        
        if extract_start != -1 and extract_end != 0:
            extracted_data = json.loads(response_text2[extract_start:extract_end])
        else:
            extracted_data = {
                "course_name": None,
                "instructors": [],
                "summary": None
            }

        # Create merged JSON output
        merged_json = {
            "course_name": extracted_data.get("course_name"),
            "instructors": extracted_data.get("instructors", []),
            "summary": extracted_data.get("summary"),
            #"full_text": initial_data.get("full_text", text),
            "full_text": initial_data_full_text,
            "full_text_no_tokens": response_tokens1
        }
        return merged_json
        
        # Format merged JSON as a readable string for Hebrew
        # readable_json = json.dumps(merged_json, ensure_ascii=False, indent=2)
        # return readable_json
   
    except (json.JSONDecodeError, ValueError) as e:
        print(f"JSON Parse Error: {str(e)}")
        print(f"LLM Response text: {response_text1 if 'response_text1' in locals() else response_text2}")
        return ({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0})
        '''
        return json.dumps({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0
        }, ensure_ascii=False, indent=2)
        '''
         
    except Exception as e:
        print(f"Error analyzing with OpenAI: {str(e)}")        
        return ({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0})
        '''
        return json.dumps({
            "course_name": None,
            "instructors": [],
            "summary": None,
            "full_text": text,
            "full_text_no_tokens": 0
        }, ensure_ascii=False, indent=2)
        '''

# %% [raw]
# def init_claude(config):
#     client = Anthropic(api_key=config['anthropic']['claud_key'])
#     return client

# %% [raw]
# def analyze_with_claude_eng(config, client, text):
#     """Analyze document content using Claude and return structured JSON data."""
#
#     prompt01 = """
#
#       You are a text extractor and analyzer top expert.
#       The text is a course syllabus document that contains the course information.
#
#        Your mission is to extract as much information as you can in the given text process it into a JSON format.
#        Required JSON structure: { "full_text": "The complete text after processing", "full_text_no_tokens": "Number tokens that chat GPT returns" }
#
#        HOW TO PROCESS THE FULL TEXT
#        1. The text will start after @@@@
#        2. Read the text very carefully.
#        3. Text may be in (Hebrew, English or mixed).
#        4. DO NOT LIMIT respone length. We need all information from the source text.
#        5. Preserve all language terms (Hebrew, English, or mixed) in their original language.
#
#        6. For the full_text field, apply these transformations
#           - Add topic sentences to each major section.
#           - Add clear section headers in capital letters.
#           - Normalize spacing and formatting.
#           - End all sentences with proper punctuation.
#           - Transform bullet points into complete sentences.
#           - Create proper paragraphs from lists.
#           - Add contextual transitions between sections.
#           - Ensure hierarchical content structure.
#           - Preserve important dates, numbers, and contact information.
#           - Remove duplicate headers/footers.
#           - Remove any text that says: "[Embedded Image ]" or similar.
#           - Maintain consistent formatting throughout.
#
#        7. Structure the text in sections
#           - COURSE NAME: course name or workshop name.
#           - COURSE OVERVIEW: course overview, or the program description.
#           - TARGET AUDIENCE: if there are.if not found, skip this section
#           - COURSE LEADERSHIP: Note for: Academic Director, Academic Leaders and their roles, Academic Advisors and Lecturers etc. - Include all leaders biography and their descriptions. if not found, skip this section.
#           - PREREQUISITES: if there are. if not found, skip this section
#           - CERTIFICATIONS AWARDED: if there are. if not found, skip this section.
#           - COURSE SCHEDULE: look for start date, end date, duration, accademic hours, schedules. be bullet focused.
#           - LEARNING FORMAT: look for things like location, in class, remote or hybrid learning options, laboratories, practicum, staj, etc. - if there are: be bullet focused. if not found, skip this section.
#           - TUITION AND FEES: look for registration fees, tuition, parking fess. if there are: be bullet focused. if not found, skip this section
#           - COURSE TOPICS: Bring all topics that appear in text. SUPER IMPORTANT TO BE DETAILED. DO NOT OMIT ANYTHING. You may orgenise topics in sections, sub-sections and under bullets.
#           - REGISTRATION AND CONTACT INFORMATION: if there are: be bullet focused. if not found, skip this section
#           - INSTITUTIONAL INFORMATION: Focused institutional information. if there are: be focused. if not found, skip this section
#
#        8. Writing style guidelines
#           - Use complete sentences.
#           - Add context to technical terms.
#           - Maintain consistent tense and voice.
#           - Ensure clarity and readability.
#           - Preserve all information from the given text.
#
#        9. Formatting requirements
#           - Use consistent paragraph spacing.
#           - Ensure proper nesting of information.
#           - Keep important identifiers (emails, URLs, phone numbers etc.) in their original format.
#
#        Text to analyze after this @@@@
#     """
#
#     try:
#         # Initial Claude call and response handling remains the same
#         message = client.messages.create(
#             model=config['anthropic']['claude_model']),
#             max_tokens=8192,
#             messages=[
#                 {
#                     "role": "user",
#                     "content": prompt01
#                 },
#                 {
#                     "role": "user",
#                     "content": text
#                 }
#             ]
#         )
#
#         response_text = message.content[0].text.strip()
#         response_tokens = message.usage.output_tokens
#
#         # Extract initial JSON
#         start = response_text.find('{')
#         end = response_text.rfind('}') + 1
#
#         if start != -1 and end != 0:
#             json_str = response_text[start:end]
#             claude_response = json.loads(json_str)
#
#             # Modified extraction prompt with explicit list format instruction
#
#             prompt2 = """
#             You are a text extractor and analyzer top expert.
#             Your mission is to extract as much information as you can in the given text process it into a JSON format.
#
#             The text is a course syllabus document that contains the course information.
#
#             HOW TO PROCESS THE TEXT
#             1. The text will start after @@@@
#             2. Read the text very carefully.
#             3. Text may be in (Hebrew, English or mixed).
#             4. Preserve all language terms (Hebrew, English, or mixed) in their original language.
#             You are a text extractor and analyzer top expert.
#             The text is a course syllabus document that contains the course information.
#
#             WHAT INFORMATION TO EXTRACT
#             1. The complete course name exactly as it appears
#
#             2. From COURSE LEADERSHIP section:
#                - Create a LIST of ALL instructors, including every teaching staff member mentioned in the text
#                - For each instructor in the list, extract:
#                  * Full name as written
#                  * Their role/position (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך, מנהל אקדמי, מוביל אקדמי)
#                  * Professional title (if mentioned)
#                  * Any additional description or background information
#                - Make sure to capture EVERY instructor mentioned, even if some details are missing
#                - List format should handle multiple instructors
#
#             3. From the entire text:
#                - Create a comprehensive course summary
#                - Do not use text from INSTITUTIONAL INFORMATION or motto.
#
#             4. Return the information in this exact JSON format:
#             {
#                 "course_name": "Complete course name as it appears",
#                 "instructors": [
#                     {
#                         "name": "First instructor name",
#                         "role": "Role (e.g., יועץ מקצועי, מרצה, מרצה בכיר, מדריך)",
#                         "title": "Professional title if available",
#                         "description": "Additional description"
#                     }
#                     // Continue for all instructors found
#                 ],
#                 "summary": "Comprehensive course summary"
#             }
#
#                 Important notes for JSON output:
#                 1. Use null for missing fields
#                 2. Use empty array [] if no instructors are found
#                 3. Maintain JSON list format even if only one instructor is found
#
#             Text to analyze after this @@@@
#             """
#
#             # Send second prompt to Claude
#             extraction_message = client.messages.create(
#                 model=config['anthropic']['claude_model']),
#                 max_tokens=8192,
#                 messages=[
#                     {
#                         "role": "user",
#                         "content": prompt2
#                     },
#                     {
#                         "role": "user",
#                         "content": claude_response.get("full_text", "")
#                     }
#                 ]
#             )
#
#             # Parse extraction response
#             extraction_text = extraction_message.content[0].text.strip()
#             extract_start = extraction_text.find('{')
#             extract_end = extraction_text.rfind('}') + 1
#
#             if extract_start != -1 and extract_end != 0:
#                 extracted_data = json.loads(extraction_text[extract_start:extract_end])
#             else:
#                 extracted_data = {
#                     "course_name": None,
#                     "instructors": [],
#                     "summary": None
#                 }
#
#             # Create final complete JSON output
#             final_json = {
#                 "course_name": extracted_data.get("course_name"),
#                 "instructors": extracted_data.get("instructors", []),
#                 "summary": extracted_data.get("summary"),
#                 "full_text": claude_response.get("full_text", text),
#                 "full_text_no_tokens": int(response_tokens)
#             }
#
#             return final_json
#
#     except (json.JSONDecodeError, ValueError) as e:
#         print(f"JSON Parse Error: {str(e)}")
#         print(f"Response text: {response_text}")
#         return {
#             "course_name": None,
#             "instructors": [],
#             "summary": None,
#             "full_text": text,
#             "full_text_no_tokens": 0
#         }
#
#     except Exception as e:
#         print(f"Error analyzing with Claude: {str(e)}")
#         return {
#             "course_name": None,
#             "instructors": [],
#             "summary": None,
#             "full_text": text,
#             "full_text_no_tokens": 0
#         }

# %% [raw]
# def analyze_with_claude_heb(config, client, text):
#     """Analyze document content using Claude and return structured JSON data in Hebrew."""
#
#     # Prompt for Hebrew output while preserving professional terms
#     prompt01 = """
#         Analyze the following text started after @@@@.
#         This text is a course syllabus document that contains the course information.
#         Your mission is to process and extract the information in JSON file format.
#
#         Required JSON structure: { "full_text": "The complete text after processing", "full_text_no_tokens": "Number tokens that claude return" }
#
#         HOW TO PROCESS THE FULL TEXT
#         1. Read the text very carefully.
#         2. Text may be in (Hebrew, English or mixed).
#         3. OUTPUT MUST BE IN HEBREW with these guidelines:
#            - Keep technical or professional terms, course names, and technical concepts in their original language
#            - Keep proper names in their original form
#            - Keep email addresses, phone numbers, and URLs in their original format
#            - Translate all descriptive and contextual content to Hebrew
#            - Use Hebrew punctuation marks where appropriate (including period at sentence end)
#            - Format numbers according to Hebrew convention
#            - Maintain Right-to-Left (RTL) formatting
#
#         4. You can use all available response tokens for output.
#
#         5. For the full_text field, apply these transformations:
#           - הוסף משפטי נושא לכל חלק עיקרי
#           - הוסף כותרות ברורות באותיות גדולות (באנגלית) או מודגשות (בעברית)
#           - נרמל רווחים ועיצוב
#           - סיים את כל המשפטים בסימני פיסוק מתאימים
#           - הפוך נקודות עם תבליטים למשפטים שלמים
#           - צור פסקאות תקינות מרשימות
#           - הוסף מעברים הקשריים בין חלקים
#           - ודא מבנה תוכן היררכי
#           - שמור על תאריכים, מספרים ופרטי קשר חשובים
#           - כלול סמנים סמנטיים ברורים למושגי מפתח
#           - הסר כותרות עליונות/תחתונות כפולות
#           - " [Embedded Image] " הסר כל טקסט כגון
#           - שמור על עיצוב עקבי לאורך כל הטקסט
#
#
#        6. מבנה הטקסט בסעיפים
#           - שם הקורס: שם הקורס המקורי. להישאר ממוקד
#           - סקירת הקורס: סקירת הקורס או תיאור התוכנית
#           - קהל יעד: אם יש. אם אין, דלג על חלק זה
#           - מובילי הקורס: הערה עבור: מנהל אקדמי, מובילים אקדמיים ונקודות המיקוד שלהם, יועצים אקדמיים ומרצים. בנוסף הבא את התאירו עליהם. אם יש. אם אין, דלג על חלק זה
#           - דרישות קדם אם יש. אם אין, דלג על חלק זה
#           - תעודות: אם יש. אם אין, דלג על חלק זה
#           - לוח זמנים: חפש תאריך התחלה, תאריך סיום, משך, לוחות זמנים. התמקד בנקודות
#           - פורמט למידה: חפש דברים כמו מיקום, בכיתה, למידה מרחוק או היברידית, מעבדות, התמחות מעשית וכו'. אם יש: התמקד בנקודות. אם אין, דלג על חלק זה
#           - שכר לימוד ותשלום: חפש דמי רישום, שכר לימוד, דמי חניה. אם יש: התמקד בנקודות. אם אין, דלג על חלק זה
#           - נושאי הקורס: הבא את כל הנושאים שמופיעים בטקסט. חשוב מאוד להיות מפורט. אל תשמיט דבר. ניתן לארגן נושאים בחלקים, תתי-חלקים ותחת תבליטים
#           - רישום ויצירת קשר: אם יש: התמקד בנקודות. אם אין, דלג על חלק זה
#           - מי אנחנו: מידע מוסדי ממוקד. אם יש: התמקד. אם אין, דלג על חלק זה
#
#        7. הנחיות סגנון כתיבה:
#           - השתמש במשפטים שלמים
#           - הוסף הקשר למונחים טכניים
#           - צור מעברים חלקים בין נושאים
#           - שמור על עקביות בזמן ובקול
#           - הבטח בהירות וקריאות
#           - שמור על כל המידע הרלוונטי מהמקור
#
#        8. דרישות עיצוב:
#           - השתמש ברווח עקבי בין פסקאות
#           - שמור על גבולות ברורים בין חלקים
#           - הבטח קינון מידע תקין
#           - השתמש בפיסוק תקני
#           - שמור על מזהים חשובים (אימיילים, מספרי טלפון, כתובות אינטרנט) בפורמט המקורי שלהם
#
#        The output JSON should maintain the same JSON structure but with the full_text field optimized for RAG applications while preserving all original information.
#
#         @@@@
#     """
#
#     try:
#         # Send the prompt to Claude and get the response
#         message = client.messages.create(
#             model="claude-3-5-sonnet-20241022",
#             max_tokens=8192,
#             messages=[
#                 {
#                     "role": "user",
#                     "content": prompt01
#                 },
#                 {
#                     "role": "user",
#                     "content": text
#                 }
#             ]
#         )
#
#         # Extract and clean up the response text
#         response_text   = message.content[0].text.strip()
#         response_tokens = message.usage.output_tokens
#
#         # Try to locate and extract JSON structure from Claude's response
#         start = response_text.find('{')
#         end = response_text.rfind('}') + 1
#         if start != -1 and end != 0:
#             json_str = response_text[start:end]
#             claude_response = json.loads(json_str)
#         else:
#             raise ValueError("No JSON found in response")
#
#         # Create ordered dictionary for the structured response
#         ordered_response1 = OrderedDict([
#             ("full_text", claude_response.get("full_text", text)),
#             ("full_text_no_tokens", int(response_tokens))
#         ])
#
#         return ordered_response1
#
#     except (json.JSONDecodeError, ValueError) as e:
#         print(f"JSON Parse Error: {str(e)}")
#         print(f"Response text: {response_text}")
#         return OrderedDict([
#             ("full_text", text),
#             ("full_text_no_tokens", 0)  # Return 0 for errors
#         ])
#
#     except Exception as e:
#         print(f"Error analyzing with Claude: {str(e)}")
#         return OrderedDict([
#             ("full_text", text),
#             ("full_text_no_tokens", 0)  # Return 0 for errors
#         ])

# %%
def process_files(config):
    """Main processing function to handle file operations using AWS S3 and the Claude service."""
    
    # Initialize AWS S3 client using provided configuration
    s3_client = init_aws_client(config)

    # Ensure the existence of a temporary directory for intermediate file storage
    tmp_dir = ensure_tmp_dir()  
           
    # Set up the JSON output directory path in the 'data/documents' folder relative to the current working directory
    json_output_dir_eng = os.path.join(os.getcwd(), 'data', 'documents', 'eng')
    os.makedirs(json_output_dir_eng, exist_ok=True)  

    # Set up the JSON output directory path in the 'data/documents' folder relative to the current working directory
    json_output_dir_heb = os.path.join(os.getcwd(), 'data', 'documents', 'heb')
    os.makedirs(json_output_dir_heb, exist_ok=True) 
    
    # Initialize Claude client using provided configuration
    # claude_client = init_claude(config)

    # Initialize OpenAi client using provided configuration
    openai_client = init_openai(config)

    # Define supported file types to process
    supported_file_types = tuple(config['local']['supported_file_types'])
    
    # List all files in AWS S3 upload bucket/path using the S3 paginator
    paginator = s3_client.get_paginator('list_objects_v2')
    pages = paginator.paginate(
        Bucket=config['aws']['sources_bucket_name'],
        Prefix=config['aws']['sources_path']
    )

    # Loop through all files in each page from the S3 bucket
    for page in pages:
        for obj in page.get('Contents', []):
            s3_file_key = obj['Key']
            file_name = os.path.basename(s3_file_key)
            
            # Process only supported file types
            if not file_name.lower().endswith(supported_file_types):
                continue

            print(f"\n=================================================================================")
            print(f"Start Processing file: {file_name}")
            
            # Create paths for the temporary PDF and output JSON
            tmp_download_file_path = os.path.join(tmp_dir, file_name)

            # Create output JSON english
            json_filename = f"{os.path.splitext(file_name)[0]}.json"
            local_json_path_eng = os.path.join(json_output_dir_eng, json_filename)

            # Create output JSON hebrew
            json_filename = f"{os.path.splitext(file_name)[0]}.json"
            local_json_path_heb = os.path.join(json_output_dir_heb, json_filename)
            
            try:
                # Download file to temporary location
                s3_client.download_file(
                    config['aws']['sources_bucket_name'], s3_file_key,
                    tmp_download_file_path
                )
                
                # Extract text from the file (including image references)
                extracted_text = extract_text_from_file(tmp_download_file_path)
                # print(f"\nExtracted Text:\n{extracted_text}")

                # Analyze text with OpenAi
                analysis_eng = analyze_with_openai_eng(config, openai_client, extracted_text)
                
                print(f"\nOpenAi Final Analysis Eng:\n{analysis_eng}")                      

                # Save analysis to JSON output file
                with open(local_json_path_eng, 'w', encoding="utf-8") as json_file:
                    json.dump(analysis_eng, json_file, ensure_ascii=False, indent=2)

                print(f"Saved analysis to {local_json_path_eng}")

                '''
                # Analyze text with Claude - english
                analysis_eng = analyze_with_claude_eng(config, claude_client, extracted_text)
                print(f"\nClaude Final Analysis Eng:\n{analysis_eng}")

                # Save analysis to JSON output file
                with open(local_json_path_eng, 'w') as json_file:
                    json.dump(analysis_eng, json_file)

                print(f"Saved analysis to {local_json_path_eng}")
                
                
                # Analyze text with Claude - hebrew
                analysis_heb = analyze_with_claude_heb(config, claude_client, extracted_text)
                print(f"\nClaude Final Analysis Heb:\n{analysis_heb}")

                # Save analysis to JSON output file
                with open(local_json_path_heb, 'w') as json_file:
                    json.dump(analysis_heb, json_file)

                print(f"Saved analysis to {local_json_path_heb}")
                '''
                
            except Exception as e:
                print(f"Error processing {file_name}: {str(e)}")
                raise

# %%
def main():
    """Main entry point"""
    try:
        config_file = 'config/config.yaml'
        config = load_config(config_file)

        process_files(config)
    
    except Exception as e:
        print(f"Main process error: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# =================================================================================
# Start Processing file: AWS Practitioner Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
#  AWS Cloud
# Practitioner
# :נושאי הקורס
# Define what the AWS Cloud is and
# the basic global infrastructure
# Describe basic AWS Cloud
# architectural principles
# Describe the AWS Cloud value
# proposition
# Describe key services on the AWS
# platform and their common use
# cases (for example, compute and
# analytics)
# Describe basic security and
# compliance aspects of the AWS
# platform and the shared security
# model
# Define the billing, account
# management, and pricing models
# Identify sources of documentation
# or technical assistance
# Describe basic/core characteristics
# of deploying and operating in the
# AWS Cloud
# 29.11.2024  :תאריך פתיחה
# 21:30-17:30 בימי שלישי בין השעות
# 13:00-09:00 בימי שישי בין השעות
#  שעות אקדמיות)50(  מפגשים10 במשך
#  בית הספר להייטק וסייבר
# אילן מזמין אתכם -של אוניברסיטת בר
# AWS ללמוד את טכנולוגיות הענן של
#  הקורס היברידי: הלימודים יתקיימו בקמפוס
# אילן בר״ג ובזום, לבחירתכם -אוניברסיטת בר
# לאורך כל הקורס
# 052-5886002 :לתאום ראיון קבלה ורישום
# esther.asulin@biu.ac.il
#
#
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
# aws@
#
# certified
#
# Cloud
# Practitioner
#
# FOUNDATIONAL
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: AWS Cloud Practitioner\n\nCOURSE OVERVIEW: The AWS Cloud Practitioner course is designed to provide participants with foundational knowledge of AWS Cloud technologies. This course is offered by the School of High-Tech and Cyber at Bar-Ilan University. Participants will learn about AWS Cloud infrastructure, services, and operational principles, enabling them to understand and utilize AWS Cloud effectively.\n\nCOURSE TOPICS: \n- Define what the AWS Cloud is and the basic global infrastructure.\n- Describe basic AWS Cloud architectural principles.\n- Explain the AWS Cloud value proposition.\n- Describe key services on the AWS platform and their common use cases, such as compute and analytics.\n- Discuss basic security and compliance aspects of the AWS platform and the shared security model.\n- Define the billing, account management, and pricing models.\n- Identify sources of documentation or technical assistance.\n- Describe basic/core characteristics of deploying and operating in the AWS Cloud.\n\nCOURSE SCHEDULE: \n- Start Date: 29.11.2024.\n- Duration: 10 sessions, totaling 50 academic hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held at Bar-Ilan University campus in Ramat Gan and via Zoom, based on participants' preference.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact Esther Asulin at 052-5886002 or via email at esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- The course is offered by the School of High-Tech and Cyber, a division of Bar-Ilan University dedicated to specialized programs.\n\nCERTIFICATIONS: AWS Certified Cloud Practitioner (Foundational)."
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "AWS Cloud Practitioner",
#     "instructors": [],
#     "summary": "The AWS Cloud Practitioner course provides foundational knowledge about AWS Cloud technologies. Participants will learn to define what the AWS Cloud is and understand its basic global infrastructure. The course covers AWS Cloud architectural principles, the value proposition of AWS Cloud, and key services on the AWS platform along with their common use cases, such as compute and analytics. It also addresses basic security and compliance aspects of the AWS platform, the shared security model, billing, account management, and pricing models. Additionally, participants will learn to identify sources of documentation or technical assistance and understand the core characteristics of deploying and operating in the AWS Cloud. The course spans 10 sessions, totaling 50 academic hours, and is offered in a hybrid format, allowing participants to choose between in-person classes at Bar-Ilan University in Ramat Gan or online via Zoom. The course is scheduled to start on 29.11.2024, with classes held on Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00."
# }
# ```
#
# OpenAi Final Analysis Eng:
# {'course_name': 'AWS Cloud Practitioner', 'instructors': [], 'summary': 'The AWS Cloud Practitioner course provides foundational knowledge about AWS Cloud technologies. Participants will learn to define what the AWS Cloud is and understand its basic global infrastructure. The course covers AWS Cloud architectural principles, the value proposition of AWS Cloud, and key services on the AWS platform along with their common use cases, such as compute and analytics. It also addresses basic security and compliance aspects of the AWS platform, the shared security model, billing, account management, and pricing models. Additionally, participants will learn to identify sources of documentation or technical assistance and understand the core characteristics of deploying and operating in the AWS Cloud. The course spans 10 sessions, totaling 50 academic hours, and is offered in a hybrid format, allowing participants to choose between in-person classes at Bar-Ilan University in Ramat Gan or online via Zoom. The course is scheduled to start on 29.11.2024, with classes held on Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.', 'full_text': "COURSE NAME: AWS Cloud Practitioner\n\nCOURSE OVERVIEW: The AWS Cloud Practitioner course is designed to provide participants with foundational knowledge of AWS Cloud technologies. This course is offered by the School of High-Tech and Cyber at Bar-Ilan University. Participants will learn about AWS Cloud infrastructure, services, and operational principles, enabling them to understand and utilize AWS Cloud effectively.\n\nCOURSE TOPICS: \n- Define what the AWS Cloud is and the basic global infrastructure.\n- Describe basic AWS Cloud architectural principles.\n- Explain the AWS Cloud value proposition.\n- Describe key services on the AWS platform and their common use cases, such as compute and analytics.\n- Discuss basic security and compliance aspects of the AWS platform and the shared security model.\n- Define the billing, account management, and pricing models.\n- Identify sources of documentation or technical assistance.\n- Describe basic/core characteristics of deploying and operating in the AWS Cloud.\n\nCOURSE SCHEDULE: \n- Start Date: 29.11.2024.\n- Duration: 10 sessions, totaling 50 academic hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held at Bar-Ilan University campus in Ramat Gan and via Zoom, based on participants' preference.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact Esther Asulin at 052-5886002 or via email at esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- The course is offered by the School of High-Tech and Cyber, a division of Bar-Ilan University dedicated to specialized programs.\n\nCERTIFICATIONS: AWS Certified Cloud Practitioner (Foundational).", 'full_text_no_tokens': 399}
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\AWS Practitioner Sylabus.json
#
# =================================================================================
# Start Processing file: AWS Solution Architect Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
#  AWS
#  Certif ied
#  Solutions
#   Architect
# Associate
# :נושאי הקורס
# Welcome to AWS Academy Cloud
# Architecting
# Introducing Cloud Architecting
# Adding a Storage Layer
# Adding a Compute Layer
# Adding a Database Layer
# Creating a Networking
# Environment
# Connecting Networks
# Securing User and Application
# Access
# Implementing Elasticity, High
# Availability, and Monitoring
# Automating Your Architecture
# Caching Content
# Building Decoupled Architectures
# Building Microservices and
# Serverless Architectures
# Planning for Disaster
# Bridging to Certification
#  הקורס היברידי: הלימודים יתקיימו בקמפוס
# אילן בר״ג ובזום, לבחירתכם -אוניברסיטת בר
# לאורך כל הקורס
#  AWS Practitioner תנאי קדם: בעלי הכשרת
# או ידע מקביל
#  בית הספר להייטק וסייבר
# אילן מזמין אתכם -של אוניברסיטת בר
# להצטרף להסמכה הבכירה בתחום הענן
# 052-5886002 :לתאום ראיון קבלה ורישום
# esther.asulin@biu.ac.il
# 01.11.2024 :תאריך פתיחה
# 21:30-17:30 בימי שלישי בין השעות
# 13:00-09:00 בימי שישי בין השעות
#  שעות אקדמיות)100(  מפגשים20 במשך
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
# aws@
# certified
#
# Solutions
#
# Architect
#
# ASSOCIATE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: AWS Certified Solutions Architect Associate\n\nCOURSE OVERVIEW: This course is designed to prepare participants for the AWS Certified Solutions Architect Associate certification. It provides comprehensive training on cloud architecture, focusing on AWS services and best practices. Participants will gain hands-on experience in designing, deploying, and managing scalable and secure applications on the AWS platform.\n\nPREREQUISITES: Participants must have completed AWS Practitioner training or possess equivalent knowledge.\n\nCOURSE SCHEDULE: \n- Start Date: 01.11.2024.\n- Duration: 20 sessions.\n- Academic Hours: 100 hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held both on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on participants' preference.\n\nCOURSE TOPICS: \n- Welcome to AWS Academy Cloud Architecting.\n- Introducing Cloud Architecting.\n- Adding a Storage Layer.\n- Adding a Compute Layer.\n- Adding a Database Layer.\n- Creating a Networking Environment.\n- Connecting Networks.\n- Securing User and Application Access.\n- Implementing Elasticity, High Availability, and Monitoring.\n- Automating Your Architecture.\n- Caching Content.\n- Building Decoupled Architectures.\n- Building Microservices and Serverless Architectures.\n- Planning for Disaster.\n- Bridging to Certification.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact: 052-5886002.\n- Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- The course is offered by the School of High-Tech and Cyber at Bar-Ilan University.\n- The program is part of Bar-Ilan University's dedicated training programs.\n\nCERTIFICATIONS: AWS Certified Solutions Architect Associate."
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "AWS Certified Solutions Architect Associate",
#     "instructors": [],
#     "summary": "The course 'AWS Certified Solutions Architect Associate' is a hybrid program offered by אוניברסיטת בר-אילן (Bar-Ilan University) through its בית הספר להייטק וסייבר (School of High-Tech and Cyber). The course covers a comprehensive curriculum designed to prepare participants for AWS certification in cloud architecture. Topics include introducing cloud architecting, adding storage, compute, and database layers, creating and connecting networking environments, securing user and application access, implementing elasticity, high availability, and monitoring, automating architecture, caching content, building decoupled architectures, microservices, and serverless architectures, planning for disaster recovery, and bridging to certification. The course requires prior AWS Practitioner certification or equivalent knowledge. It spans 20 sessions over 100 academic hours, with classes held on Tuesdays (17:30-21:30) and Fridays (09:00-13:00). The program begins on 01.11.2024 and offers flexibility for participants to attend either on-campus at בר-אילן or via Zoom."
# }
# ```
#
# OpenAi Final Analysis Eng:
# {'course_name': 'AWS Certified Solutions Architect Associate', 'instructors': [], 'summary': "The course 'AWS Certified Solutions Architect Associate' is a hybrid program offered by אוניברסיטת בר-אילן (Bar-Ilan University) through its בית הספר להייטק וסייבר (School of High-Tech and Cyber). The course covers a comprehensive curriculum designed to prepare participants for AWS certification in cloud architecture. Topics include introducing cloud architecting, adding storage, compute, and database layers, creating and connecting networking environments, securing user and application access, implementing elasticity, high availability, and monitoring, automating architecture, caching content, building decoupled architectures, microservices, and serverless architectures, planning for disaster recovery, and bridging to certification. The course requires prior AWS Practitioner certification or equivalent knowledge. It spans 20 sessions over 100 academic hours, with classes held on Tuesdays (17:30-21:30) and Fridays (09:00-13:00). The program begins on 01.11.2024 and offers flexibility for participants to attend either on-campus at בר-אילן or via Zoom.", 'full_text': "COURSE NAME: AWS Certified Solutions Architect Associate\n\nCOURSE OVERVIEW: This course is designed to prepare participants for the AWS Certified Solutions Architect Associate certification. It provides comprehensive training on cloud architecture, focusing on AWS services and best practices. Participants will gain hands-on experience in designing, deploying, and managing scalable and secure applications on the AWS platform.\n\nPREREQUISITES: Participants must have completed AWS Practitioner training or possess equivalent knowledge.\n\nCOURSE SCHEDULE: \n- Start Date: 01.11.2024.\n- Duration: 20 sessions.\n- Academic Hours: 100 hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held both on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on participants' preference.\n\nCOURSE TOPICS: \n- Welcome to AWS Academy Cloud Architecting.\n- Introducing Cloud Architecting.\n- Adding a Storage Layer.\n- Adding a Compute Layer.\n- Adding a Database Layer.\n- Creating a Networking Environment.\n- Connecting Networks.\n- Securing User and Application Access.\n- Implementing Elasticity, High Availability, and Monitoring.\n- Automating Your Architecture.\n- Caching Content.\n- Building Decoupled Architectures.\n- Building Microservices and Serverless Architectures.\n- Planning for Disaster.\n- Bridging to Certification.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact: 052-5886002.\n- Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- The course is offered by the School of High-Tech and Cyber at Bar-Ilan University.\n- The program is part of Bar-Ilan University's dedicated training programs.\n\nCERTIFICATIONS: AWS Certified Solutions Architect Associate.", 'full_text_no_tokens': 432}
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\AWS Solution Architect Sylabus.json
#
# =================================================================================
# Start Processing file: Advanced Project Management Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
#  Advanced
#  Project
# Management
# 13.01.2025 :תאריך פתיחה
# בימים שני וחמישי
# 21:30-17:30 בין השעות
#  שעות אקדמיות)25(  מפגשים5 במשך
#  בית הספר להייטק וסייבר
# אילן מזמין אתכם -של אוניברסיטת בר
# לסדנת ניהול של פרויקטים בתחום הדאטה
# לתאום ראיון קבלה ורישום:
# 052-5886002
# esther.asulin@biu.ac.il
#  הקורס  היברידי:  הלימודים  יתקיימו  בקמפוס
# אילן  בר״ג  ובזום,  לבחירתכם -אוניברסיטת  בר
# לאורך כל הקורס
# Advanced Project Management aimed for
# Data Products
# •
# CDAIO Agile projects management
# •
# Scrum & Kanban
# •
# Data products management
# •
# Project and tasks management tools
#  Executive look at Project Management
# •
# PMI & PMO
# •
# Leading factors towards project Initiation
# •
# Mitigating the Key Reasons for Project
# Failure
# •
# Interrelationships between Project,
# Program, and Portfolio
# •
# Traditional, Hybrid, and Agile Project
# Management key considerations
# •
# Organizational Structures and their impact
# on Project Management
# •
# Reviewing the 10 knowledge areas and 49
# Project Management Processes
# •
# Leadership styles, Handling dilemmas and
# crisis
# •
# Effectiveness vs. Efficiency
# •
# Effective Time Management –
# Prioritization, Desk Clearing, Reducing
# Distractions, Dynamic List
# •
# Project Integration Process
# •
# Using AI as a co-pilot for project
# management process
# :נושאי הקורס
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: Advanced Project Management.\n\nCOURSE OVERVIEW: This course is a workshop focused on project management in the field of data products. It is designed to provide participants with advanced skills and methodologies for managing projects effectively, with a particular emphasis on data-driven projects. The program is offered by Bar-Ilan University's School of High-Tech and Cyber.\n\nCOURSE SCHEDULE: \n- Start Date: January 13, 2025.\n- Schedule: Mondays and Thursdays, from 17:30 to 21:30.\n- Duration: 5 sessions.\n- Total Academic Hours: 25 hours.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held both on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on participants' preferences.\n\nCOURSE TOPICS: \n1. Advanced Project Management aimed for Data Products:\n   - CDAIO Agile projects management.\n   - Scrum & Kanban methodologies.\n   - Data products management.\n   - Project and tasks management tools.\n\n2. Executive Look at Project Management:\n   - PMI & PMO frameworks.\n   - Leading factors towards project initiation.\n   - Mitigating the key reasons for project failure.\n   - Interrelationships between project, program, and portfolio.\n   - Traditional, hybrid, and agile project management key considerations.\n   - Organizational structures and their impact on project management.\n   - Reviewing the 10 knowledge areas and 49 project management processes.\n   - Leadership styles, handling dilemmas, and crisis management.\n   - Effectiveness vs. efficiency in project management.\n   - Effective time management, including prioritization, desk clearing, reducing distractions, and dynamic list creation.\n   - Project integration process.\n   - Using AI as a co-pilot for the project management process.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register:\n  - Phone: 052-5886002.\n  - Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- Offered by Bar-Ilan University.\n- School of High-Tech and Cyber.\n- Dedicated programs division.\n\nTUITION AND FEES: Not specified in the provided text.\n\nPREREQUISITES: Not specified in the provided text.\n\nCERTIFICATIONS: Not specified in the provided text.\n\nTARGET AUDIENCE: Not specified in the provided text.\n\nCOURSE LEADERSHIP: Not specified in the provided text."
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "Advanced Project Management",
#     "instructors": [],
#     "summary": "The Advanced Project Management course is a hybrid program offered by Bar-Ilan University's School of High-Tech and Cyber. The course focuses on project management in the field of data products and includes topics such as CDAIO Agile project management, Scrum & Kanban, data products management, and project and task management tools. It provides an executive perspective on project management, covering PMI & PMO, project initiation, mitigating key reasons for project failure, and understanding the interrelationships between project, program, and portfolio. The course also explores traditional, hybrid, and agile project management considerations, organizational structures' impact on project management, and a review of the 10 knowledge areas and 49 project management processes. Additional topics include leadership styles, handling dilemmas and crises, effectiveness vs. efficiency, effective time management strategies, project integration processes, and the use of AI as a co-pilot in project management. The course is conducted over five sessions, each lasting five academic hours, and is available both on-campus in Ramat Gan and via Zoom."
# }
# ```
#
# OpenAi Final Analysis Eng:
# {'course_name': 'Advanced Project Management', 'instructors': [], 'summary': "The Advanced Project Management course is a hybrid program offered by Bar-Ilan University's School of High-Tech and Cyber. The course focuses on project management in the field of data products and includes topics such as CDAIO Agile project management, Scrum & Kanban, data products management, and project and task management tools. It provides an executive perspective on project management, covering PMI & PMO, project initiation, mitigating key reasons for project failure, and understanding the interrelationships between project, program, and portfolio. The course also explores traditional, hybrid, and agile project management considerations, organizational structures' impact on project management, and a review of the 10 knowledge areas and 49 project management processes. Additional topics include leadership styles, handling dilemmas and crises, effectiveness vs. efficiency, effective time management strategies, project integration processes, and the use of AI as a co-pilot in project management. The course is conducted over five sessions, each lasting five academic hours, and is available both on-campus in Ramat Gan and via Zoom.", 'full_text': "COURSE NAME: Advanced Project Management.\n\nCOURSE OVERVIEW: This course is a workshop focused on project management in the field of data products. It is designed to provide participants with advanced skills and methodologies for managing projects effectively, with a particular emphasis on data-driven projects. The program is offered by Bar-Ilan University's School of High-Tech and Cyber.\n\nCOURSE SCHEDULE: \n- Start Date: January 13, 2025.\n- Schedule: Mondays and Thursdays, from 17:30 to 21:30.\n- Duration: 5 sessions.\n- Total Academic Hours: 25 hours.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held both on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on participants' preferences.\n\nCOURSE TOPICS: \n1. Advanced Project Management aimed for Data Products:\n   - CDAIO Agile projects management.\n   - Scrum & Kanban methodologies.\n   - Data products management.\n   - Project and tasks management tools.\n\n2. Executive Look at Project Management:\n   - PMI & PMO frameworks.\n   - Leading factors towards project initiation.\n   - Mitigating the key reasons for project failure.\n   - Interrelationships between project, program, and portfolio.\n   - Traditional, hybrid, and agile project management key considerations.\n   - Organizational structures and their impact on project management.\n   - Reviewing the 10 knowledge areas and 49 project management processes.\n   - Leadership styles, handling dilemmas, and crisis management.\n   - Effectiveness vs. efficiency in project management.\n   - Effective time management, including prioritization, desk clearing, reducing distractions, and dynamic list creation.\n   - Project integration process.\n   - Using AI as a co-pilot for the project management process.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register:\n  - Phone: 052-5886002.\n  - Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: \n- Offered by Bar-Ilan University.\n- School of High-Tech and Cyber.\n- Dedicated programs division.\n\nTUITION AND FEES: Not specified in the provided text.\n\nPREREQUISITES: Not specified in the provided text.\n\nCERTIFICATIONS: Not specified in the provided text.\n\nTARGET AUDIENCE: Not specified in the provided text.\n\nCOURSE LEADERSHIP: Not specified in the provided text.", 'full_text_no_tokens': 554}
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\Advanced Project Management Sylabus.json
#
# =================================================================================
# Start Processing file: BI Fin Ops Sylabus.pdf
#
#  Extracted text and images contetnt
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#
#
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
# בית הספר
#
# להייטק וסייבר
# המערר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
# AWS academy
# SO,
#
# * לימודים לא אקדמיים
#
# Certified Business Intelligence Developer
# and FinOps Specialist
#
# לימודי תעודה
# להכשרת מפתחי
# בינה עסקית ,
# ומומחי ‎FinOps‏
#
# בולל הכנה לבחינת ההסמכה הבינ"ל
# ‎AWS Practitioner‏
#
# אוניברסיטת בר-אילן, המערך לתוכניות ייעודיות
# המדור לתוכניות מובנות ולימודי תעודה
# ‎hitech-school.biu.ac.il‏ | טלפון: 052-5886002
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#
#
# Business Intelligence Developer &
# FinOps Specialist
#
# המסלול השלם להכשרת מפתחי בינה עסקית
#   ומומחיFinOps
#
#
#
#
#  מנהל
# התוכנית :
#
#  מר ערן שחם, מנהל
# בית הספר ל
# הייטק וסייבר באוניברסיט
# ת בר-אילן
# :יועצים מקצועיים
#  מר דורון יעקובוב
#
#
#   תחום  הבינה  העסקית(Business Intelligence)
#
#   .הינו  תחום  מרכזי  בטכנולוגיות  המידע  בשנים
#   האחרונות
# עולה  הצורך לטיפול בכמויות אדירות של מידע  , ו
# השפע ה של
#   התובנות העסקיות
# הופכת
#  משמעותית
# .יותר ויותר
#  תוכנית הלימודים
#   של ביה"ס להייטק וסייבר
# מכשירה
#   מומחי בינה עסקית
# במחקר
#   נתונים בו פיתוח
#  טכניקות להפקת תובנות עסקיות .  מהמידע הגולמי הנמצא במאגר החברה
#  מופק
#  ידע תחרותי בעל ערך מוסף
# למנהלי החברה  .
#
#
# במהלך הקורס ,
#   התלמיד  מתקין בסיס נתונים מבוססSQL Server
#
#   ,
#   מבצע שאילתות בSQL
#   וב -
# Python
#   , ממשיך בפיתוחיFront End
#     וBack End
#   (
# SSIS
#   ) ומסיים עם בנייתDashboard
#
#  איכותי באמצעות ו
#  מציג התלמיד את התובנות .העסקיות
#  בנוסף  לטכנולוגיות ה -
# BI
#   ,
#   נחשף התלמיד במהלך הקורס ל
# תחום הענן וה -
# Financial Operations
#   .
#   לטכנולוגיית
# הענן קיימים יתרונות רבים:
#  גמישות, גישה רחבה לכל אנשי הארגון, מגוון רחב של שירותים ועוד.
#   ,אולם  בתוך
#   יתרונות אלו מסתתר האתגר הגדול ביותר של משתמשי הענן : שליטה בעלויות הענן ובקרה על אופי השימוש
#  .בו
#
#  תחום ה-
# FinOps
#
#  : כולל בתוכו שני עולמות מרכזיים
#
# •
#
# ( שליטה בעלויות הענןCost Control
#  )
# –
#
#  על בסיס אנליזות, דו"חות, התראות, תיוג משאבים 'וכו .
#
# •
#
#  (  ייעול  ניצול  השימוש  בענןCost Optimization
# )
# –
#   באמצעות  הבנה  טכנולוגית
#  מעמיקה  ,  כלים
#  פיננסיים
# ו  .שינויים ארכיטקטוניים ככל  שטכנולוגיות הענן חודרות אל חיינו,
#   וחברות רבות מעבירות את
#   ,תשתיות השרתים והאפליקציות אל הענן  כך  נוצר צורך גדול בשוק לאנשי מקצוע המסוגלים לקבל
#   החלטות עסקיות בנושאי הBilling
#   וה
# Cost Optimization
#   ,
#   ולהחליט  בין פתרונות  ענן
#  של
#  יצרנים
# שונים .
#
#  כאקדמיה
#  מורשית
#   שלAWS
#
#   בישראל, נפתח לתלמיד חשבון באתר האקדמיה שלAWS
#
#   והוא לומד
# את
#  טכנולוגיות
#  הענן
#  של  היצרן
#  תוך
#  התנסות
#  מעשית
#   ואף ניגש לבחינה הבינ"לAWS Practitioner
#  .
#
# בשלב
#   הבא  התלמיד
# י תמחה  במגוון
#   טכנולוגיותFinOps
#   ו  יתרגל יכולות אלו על בסיסData
#
#   הדומה
#  .לנעשה בעולם האמיתי
#
# התחומים
# BI Developer
#    ו-
# FinOps Specialist
#
#   פותחים בפני תלמידים בעלי רקע פיננסי חלון הזדמנויות
#  .בעולם  התעסוקה,  תוך  קבלת  ארגז  כלים  טכנולוגי  משמעותי  ושימור  היתרון  היחסי  של  הידע  הקודם
# תיק
#  העבודות,
#  אותו  יוצר
#  התלמיד  בקורס,  ניתן  להצגה
#  מול  מעסיקים
#  בתהליך  הקבלה  למשרות  בתחומים
#  אלו .
#
#
#
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#
#  יתרונותיה הבולטים של התוכנית
#
# o
#  תוכנית מקי
# פה
#   .לתחקור נתונים
# o
#  שתי תעודות אוניברסיטאיות לשתי התמחויות שונות
#  .ונדרשות
# o
#
#  הכרות עם טכנולוגיותdashboarding
#
#  .וענן בקורס אחד
# o
#  מיקוד בכלים הנפוצים בתחום, ממוקדים
# Microsoft SQL Server
#  .
#
# o
#
#  מודולAdvanced SQL
#  ,
#   אשר לוקח את התלמידים מעבר לרמת הבסיסית הנלמדת ברוב המסלולים
# ומכין
#   .אותם לראיונות עבודה ואתגרים בעולם האמיתי
# o
#  ה קורס הוא ,מעשי במהותו
# ו משלב יישום תרגולים רבים ובניית פרויקט אישי,
#   במקביל לידע התיאורטי
# ה
# רב ה
# נרכש
#  .במהלכו
# o
#
#  לרשות התלמידים עומדות  .סביבות תרגול וירטואליות מתקדמות שהוקמו במיוחד לכל מודל
# o
#  סדנ
# או ת הכרות  מעמיקה
# עם שוק התעסוקה  ו-
# Linkedin
#  ,
#   כתיבת קורות חיים, חיפוש עבודה ומיתוג אישי  ,
# במטרה
#  .לסייע לתלמיד להשתלב היטב בשוק העבודה ולהבליט את כישוריו
# o
#
#   סדנת"
#  פרזנטציה מנצחת" ,
#  באמצעותה משפר  התלמיד את יכולות
# יו
#  .להציג פרויקט
# o
#
#  .ליווי אישי של התלמיד לאורך כל המסלול וגם לאחריו
#
#   אודות מנהל
#   התוכנית ,ומנהל בית הספר להייטק וסייבר מר ערן שחם
#
# o
#
#  בעל ניסיון עשיר של למעלה מ-
# 30
#
#   .שנים כמרצה ומנהל הדרכות בתחום הסייבר ואבטחת המידע
# o
#
#  מנהל בית הספר להייטק וסייבר של
# אוניברסיטת בר -איל  .ן
# o
#
#   מנהל מרכזי הדרכה מורשים של החברות המובילות בעולם בתחום הווירטואליזציה, תקשורת ואבטחת
#   מידעISC2, Forcepoint, Check Point, EC-Council, VMware, Amazon AWS
#
#   ומכשיר
#  .אינטגרטורים בקורסים המתקדמים
# o
#
#   מכשיר לקוחות ושותפים שלCheck Point
#   בטכנולוגיות מתקדמות כ-
# 20
#
#  .שנה
# o
#  יזם, הקים וניהל את  קורסי  התעודה במחשבים
#   ביחידה ללימודי המשך של"מוסד הטכניון"
#   במשך8
#
#   ,שנים
#  .בת"א, חיפה וירושלים
# o
#
#   הקים וניהל את "מלם-תים
# "הדרכה , מקבוצת "מלם-תים", האחראית להכשרת
# 4,000
#
#  עובדי הקבוצה .
#
# o
#
#  .ניהל את קהילת אבטחת המידע במיקרוסופ ישראל
#
#   אודות
# היועץ המקצועי ו המרצה ,
#  מר
# דורון יעקבוב
#
# o
#
# Data Product Manager
#
#   בחברתMobileye
#
#
# o
#
#  בעל ניסיון עשיר בניהול פרוייקטים
#   מקצה לקצה בשווקים הבטחוניים והמוניציפאליים, בדגש על טכנולוגיות
# IoT
#   .
#
# o
#  בעל ניסיון רב בהדרכה (כ-
# 10
#
#   .שנים) כמרצה ומנהל הדרכות בעולמות התוכנה והדאטא
# o
#  בעל תואר ראשון בהנדסת חשמל ואלקטרוניקה, בהתמחות מערכות משובצות
#  .מחשב
#
#
#   אודות
# המרצה  ,
#  מר
# ליאור לריאה
#
#
# o
#
#  מוביל מקצועי של
# טכנולוגיות ה-
# dashboarding
#
#  בקורס .
#
# o
#
#  מרצה מומחה שלTableau
#  .
#
# o
#  בעל נ
# י סיון של24
#  שנים בעולמות הדאטה .
#
#
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#   אודות
# המרצה  ,מר איליה לוין
#
#
# o
#
#  מוביל מקצועי של  טכנולוגיותAWS
#  בקורס  ו מרצה מוסמך מטעםAWS
#  .
#
# o
#
#  ארכיטקט ענן ו-
# Training Specialist
#  בחטיבת הענן בדלויט.
#
# o
#
#  בעל
# 6
#
#  הסמכות של AWS
#  ובעל
# 4
#
#   הסמכות שלGCP
#  .
#
# o
#
#  ותק של10
#
#  שנים בהדרכות והנחיה מקצועית .
#
#
#  קהל יעד
#
# o
#
#   בוגרי מנהל עסקים, כלכלה, חשבונאות, רו"ח, מערכות מידע ומועמדים בעלי רקע עסקי המעוניינים
#  .בשילוב של תהליכים עסקיים עם כלים טכנולוגיים
#
#  דרישות קדם
#
# o
#
#   ראיון קבלה ע"י יועץ .לימודים
# o
#
#  .קריאה והבנה ברמה טובה של אנגלית טכנית
#
#  מתכונת לימודים
#
# o
#  פתיחת הלימודים :
#
# 17.12.2024
#
# o
#
#  משך הלימודים:
#
#  ,כשישה חודשים
# בימי  שלישי
# בין השעות
# 17:30
#
#  –
#
# 21:30
#
#   ובימי שישי בין השעות
#
# 09:00
#
# –
#
# 13:00
#  .
#
#   *
#
#  שיעורי השלמה יתכנו בימים שאינם ימי הלימוד הרגילים .
#
# o
#
#  תוכנית הלימודים כוללת200
#   שעות אק
# ד
# מיות פרונטליו ת .
#
#
#  שכר לימוד
#
# o
#
#  :דמי רישום
# 480
#
# ₪
#  .
#
# o
#
#  :שכר לימוד
# 12,500
#
#  ₪
#  .
#
# o
#
#  :בחינות
#  בחינות ההסמכה הבינלאומיות הינן חיצוניות ובתשלום נוסף .למרכז הבחינות
#
#
#  מקום הלימוד
#
# o
#
#  הלימודים נערכים בבית הספר להייטק וסייבר  ,
#  קמפוס
# אוניברסיטת בר-
#  אילן, רמת גן .
#
# o
#
#  בהתאם להוראות פיקוד העורף והוראות האוניברסיטה ייתכן שחלק מהשיעורים יועברו באמצעות זום .
#
#
#  זכאות לתעודה
#
# o
#  חובת נוכחות ב-
# 80%
#  מהמפגשים, ועמידה במטלות ה
# תוכנית
#  .ובפרזנטציית הסיום
# o
#  לעומדים בדרישות ה
# תוכנית
#  יוענקו שתי תעוד
# ות
#   מטעם ,אוניברסיטת בר אילן .ביה"ס להייטק וסייבר
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#  הערות
#
# o
#
#  פתיחת כל תוכנית
#  .מותנית במספר הנרשמים
# o
#
#   דמי ההרשמה אינם  כלולים בשכר הלימוד ואינם
# מוחזרים, אלא במקרה של אי פתיחת ה
# תוכנית
#   על ידי
# היחידה ., בכפוף לתקנון לימודים של לימודי התעודה באוניברסיטת בר אילן
# o
#  היחידה מביאה לידיעת הנרשמים כי ייתכנו שינויים במערך ה
# תוכנית  , במועדי הלימודים והבחינות או בכל
# נושא אחר. הודעה על כל שינוי תימסר למשתתפים ,  ב  כפוף לתקנון לימודי התעודה באוניברסיטת בר-
#  א .ילן
#
#  נהלי רישום
#
# o
#
#   ההרשמה תתבצע באמצעות
# חברת ערן שחם בע"מ, עבור אוניברסיטת בר אילן .
#
#
#
#
#
#  תעודות הסיום של הקורס
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
# לפרטים והרשמה נא לפנות אל:
# אסתר אסולין
#
# 052-5886002
# esther.asulin@biu.ac.il
#
# WY
#
# ~
#
# 6
# \
#
#
# Bar-Ilan
#
# The Center for Designated Programs.
#
# Certificate Study Program
#
# This sto catty that
#
# Israel Israeli
#
# Lo. 123456789
#
# Has successfully completed all studies and
# requements of the course
#
# FinOps Specialist
#
# ‘Atala of 40 study hours ware completed curing
# ‘January 19, 2024 ‏ו‎ 16th, 2024
#
# Ramat Gan eras!
#
# February 16th, 2024
#
# Ege Shaka ‏לל‎
#
# Me Eran Shaham Prof. Noa Vichineky
#
# anager. Soret of Head of Designates
# ‏בר‎ Progams and Ceiate
# Seeurty Stostes Commitee
# Ahiad Tdan
#
# Program anager
#
#
#
# “The Conter for Designated Programs
#
# Certificate Study Program
#
# This sto corty that
#
# Israel Israeli
#
# tp. r23486789
#
# Has successfully completed a studies and
# Fequrements ofthe course
#
# Business Intelligence
# Developer
#
# total of 175 study hours were completed during
# (October 10%, 2023 = March 12m, 2026
#
# Ramat Gan, Israel
#
# Maren #2tn, 2004
#
# Talia Morchi
#
# Mr. Talia Moreh
# Proyam Manager
#
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#
#  תוכנית
#  הלימודים
#
# Intro to Business Intelligence + SQL Basics (20 Academic Hours  ( :
#
# o Familiarity with BI
# o Functions and job role of BI Analyst
# o Basic select statements
# o Filtering and sorting the results
# o Scalar functions
# o Group functions
# o Join methods
# o Sub Queries
# o Add, modify, or remove data from a table (DML)
#
# Managing SQL Objects (10 Academic Hours):
#
# o Creating and managing tables
# o Working with Indexes
# o Understanding Execution Plans
#
# T-SQL Programming (5 Academic Hours):
# o Working with variables
# o Loops and conditions
# o Creating and using stored procedures
# o Creating and using functions
# o Cursors
# o Error Handling  and Triggers
#
# Advanced SQL Querying (20 Academic Hours):
#
# o Using CTEs and Recursion
# o Advanced usage of subqueries
# o Analytic Functions
# o Window Functions
#
# Business Intelligence and Dashboarding Using MS Excel
# (10 Academic Hours):
#
# o Reference Types
# o Working with Data Tables
# o Statistical Functions
# o Pivot Tables
# o Merging data using VLookup, and XLookup
# o Advanced reporting using array functions
# o Building and customizing dashboards
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
#
# Introduction to Data Using Python (40 Academic Hours):
#
# o Python language fundamentals
#
# –
#
# Variables, program flow, functions, data structures
# o Using Python to import and shape data from varied sources
# o Data Analysis using the Pandas library
# o Data Visualization
#
# SQL Server Integration Services- SSIS (25 Academic Hours):
#
# o Introduction to DWH concepts
# o Introduction to SQL Server Integration Services
# o Developing Integration Services Solutions
# o Implementing Control Flow
# o Implementing Data Flow and SCD Methodologies
# o Configuring and Deploying Packages
#
# Creating Reports and Dashboards with Tableau
# (25 Academic Hours):
#
# o Tableau Basic Workflow & Features
# o Using Visualizations To Present Data
# o Using Calculations & Formulas
# o Joining Data From Different Sources
# o Data Preparation
# o Visuals, Dashboards and Stories
# o Advanced techniques in Tableau
# o Parameters and Analytics
#
# AWS Cloud Practitioner  (15 Academic Hours):
#
# o Define what the AWS Cloud is and the basic global infrastructure
# o Describe basic AWS Cloud architectural principles
# o Describe the AWS Cloud value proposition
# o Describe key services on the AWS platform and their common use cases
# (for example, compute and analytics)
# o Describe basic security and compliance aspects of the AWS platform and the shared
# security model
# o Identify sources of documentation or technical assistance
# o Describe basic/core characteristics of deploying and operating in the AWS Cloud
#
# FinOps Specialist  (25 Academic Hours):
#
# o Cloud Concept and overall review.
# o Main Cloud Services.
# o FinOps – What is it and why is it needed?
# o Cloud pricing and billing
# o Finance tools and options (commitments, agreements, etc.)
# o AWS cost explorer introduction.
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#
# המערך
#   לתוכניות ייעודיות
#
#
# The Center for Designated Programs
#
#
# בית הספר להייטק וסייבר
#
#
#
#
#              School of Hi-Tech and Cyber Security
#
# b a r i l a n . a c . i l
#  :מוקד המידע לשירותך*9392
#
# משרד ראשי
# 03-5318254
#
# DesigProg.biu.ac.il
# המדור לתוכניות מובנות
# 03-5317957
#
# DesigProg.biu.ac.il
# המדור לזרועות הביטחון
# 03-5317005/6
#
# mzb.biu.ac.il
# מכינה קדם אקדמית
# 03-5317956
#
# mechina-kda.biu.ac.il
# קמפוס חרדי
# 077-2753094/8
#
# DesigProg.biu.ac.il
# לימודי תעודה
# 03-7384481
#
# biu-es.ac.il
# o Use case + brainstorming.
# o Cost Control – Tags, Alerts, Budgeting, etc.
# o Use case + brainstorming.
# o K8S- Introduction, high-level technical review, FinOps POV.
# o FinOps third-party tools and products.
# o Cloud cost monitoring.
# o Tips for success + best practices.
# o Final Exam/Exercise – based on AWS Cost Explorer.
#
# Personal Branding in a changing Job Market (5 Academic Hours) :
#
# o How to reach your dream job
# o Digital platforms for personal branding
# o Leveraging use of Linkedin for job search
# o Guidelines for writing CV’s and how to manage ATS
# (Applicant Tracking Systems)
# o Building a professional plan for career development
#
# Building a winning presentation (5 Academic Hours) :
#
# o The importance of presentations
# o Using tools and techniques for creating presentations
# o Learning how to demonstrate your speech in public speaking
# o Connecting the skills to your final project presentation
#
# Final Presentation and Course Graduation (10 Academic Hours)
#
#
#
# **
#
#  המערך לתוכניות ייעודיות שומר לעצמו את הזכות לערוך
# שינויים ב
# תוכנית
#   .הלימודים
#
#
#
#
#
#
#
#
#
# ‎wr‏ אוניברסיטת בר-אילן
#
#
#
#
#
#
#
#
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: Certified Business Intelligence Developer and FinOps Specialist.\n\nCOURSE OVERVIEW: This program is designed to train participants as Business Intelligence Developers and FinOps Specialists. It includes preparation for the international AWS Practitioner certification. The program focuses on equipping students with the skills to analyze large volumes of data, derive business insights, and manage cloud financial operations effectively. Students will gain hands-on experience with SQL Server, Python, Tableau, and AWS technologies, culminating in a comprehensive portfolio to present to potential employers.\n\nTARGET AUDIENCE: Graduates in Business Administration, Economics, Accounting, Certified Public Accountants, Information Systems, and candidates with a business background interested in integrating business processes with technological tools.\n\nCOURSE LEADERSHIP: \n- Program Manager: Mr. Eran Shaham, Director of the School of Hi-Tech and Cyber Security at Bar-Ilan University. With over 30 years of experience in cybersecurity and information security training, he has managed advanced training centers and developed certification programs for leading global companies.\n- Professional Advisor and Lecturer: Mr. Doron Yakubov, Data Product Manager at Mobileye, with extensive experience in project management and data technologies, and a background in Electrical and Electronics Engineering.\n- Lecturer: Mr. Lior Laria, a Tableau expert with 24 years of experience in data technologies.\n- Lecturer: Mr. Ilya Levin, AWS-certified instructor and Cloud Architect at Deloitte, with 10 years of professional training experience.\n\nPREREQUISITES: \n- Admission interview with an academic advisor.\n- Good reading and comprehension skills in technical English.\n\nCERTIFICATIONS: AWS Practitioner, Business Intelligence Developer, FinOps Specialist.\n\nCOURSE SCHEDULE: \n- Start Date: December 17, 2024.\n- Duration: Approximately six months.\n- Schedule: Tuesdays (17:30–21:30) and Fridays (09:00–13:00).\n- Academic Hours: 200 hours of frontal instruction.\n\nLEARNING FORMAT: \n- Location: School of Hi-Tech and Cyber Security, Bar-Ilan University, Ramat Gan.\n- Some classes may be conducted via Zoom, subject to university and Home Front Command guidelines.\n- Practical exercises and virtual training environments are provided for each module.\n\nTUITION AND FEES: \n- Registration Fee: 480₪.\n- Tuition Fee: 12,500₪.\n- International certification exams are external and require additional payment.\n\nCOURSE TOPICS: \n1. Intro to Business Intelligence + SQL Basics (20 Academic Hours):\n   - Introduction to BI and the role of a BI Analyst.\n   - SQL basics including select statements, filtering, sorting, scalar functions, group functions, joins, subqueries, and data manipulation.\n\n2. Managing SQL Objects (10 Academic Hours):\n   - Creating and managing tables, indexes, and execution plans.\n\n3. T-SQL Programming (5 Academic Hours):\n   - Variables, loops, conditions, stored procedures, functions, cursors, error handling, and triggers.\n\n4. Advanced SQL Querying (20 Academic Hours):\n   - CTEs, recursion, advanced subqueries, analytic functions, and window functions.\n\n5. Business Intelligence and Dashboarding Using MS Excel (10 Academic Hours):\n   - Data tables, statistical functions, pivot tables, advanced reporting, and dashboard creation.\n\n6. Introduction to Data Using Python (40 Academic Hours):\n   - Python fundamentals, data analysis with Pandas, and data visualization.\n\n7. SQL Server Integration Services (SSIS) (25 Academic Hours):\n   - Data warehouse concepts, integration services, control flow, data flow, and package deployment.\n\n8. Creating Reports and Dashboards with Tableau (25 Academic Hours):\n   - Tableau basics, data preparation, visualizations, dashboards, and advanced techniques.\n\n9. AWS Cloud Practitioner (15 Academic Hours):\n   - AWS Cloud fundamentals, architecture, services, security, an ...
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "Certified Business Intelligence Developer and FinOps Specialist",
#     "instructors": [
#         {
#             "name": "מר ערן שחם",
#             "role": "מנהל התוכנית",
#             "title": null,
#             "description": "מנהל בית הספר להייטק וסייבר באוניברסיטת בר-אילן. בעל ניסיון עשיר של למעלה מ-30 שנים כמרצה ומנהל הדרכות בתחום הסייבר ואבטחת המידע. מנהל מרכזי הדרכה מורשים של החברות המובילות בעולם בתחום הווירטואליזציה, תקשורת ואבטחת מידע כגון ISC2, Forcepoint, Check Point, EC-Council, VMware, Amazon AWS. יזם, הקים וניהל קורסי תעודה במחשבים ביחידה ללימודי המשך של הטכניון במשך 8 שנים. ניהל את קהילת אבטחת המידע במיקרוסופט ישראל."
#         },
#         {
#             "name": "מר דורון יעקובוב",
#             "role": "יועץ מקצועי ומרצה",
#             "title": "Data Product Manager",
#             "description": "עובד בחברת Mobileye. בעל ניסיון עשיר בניהול פרויקטים מקצה לקצה בשווקים הביטחוניים והמוניציפאליים, בדגש על טכנולוגיות IoT. בעל ניסיון רב בהדרכה (כ-10 שנים) כמרצה ומנהל הדרכות בעולמות התוכנה והדאטה. בעל תואר ראשון בהנדסת חשמל ואלקטרוניקה, בהתמחות מערכות משובצות מחשב."
#         },
#         {
#             "name": "מר ליאור לריאה",
#             "role": "מרצה",
#             "title": null,
#             "description": "מוביל מקצועי של טכנולוגיות ה-dashboarding בקורס. מרצה מומחה של Tableau. בעל ניסיון של 24 שנים בעולמות הדאטה."
#         },
#         {
#             "name": "מר איליה לוין",
#             "role": "מרצה",
#             "title": "Training Specialist",
#             "description": "מוביל מקצועי של טכנולוגיות AWS בקורס ומרצה מוסמך מטעם AWS. ארכיטקט ענן ו-Training Specialist בחטיבת הענן בדלויט. בעל 6 הסמכות של AWS ובעל 4 הסמכות של GCP. ותק של 10 שנים בהדרכות והנחיה מקצועית."
#         }
#     ],
#     "summary": "התוכנית 'Certified Business Intelligence Developer and FinOps Specialist' של אוניברסיטת בר-אילן, המערך לתוכניות ייעודיות, נועדה להכשיר מפתחי בינה עסקית ומומחי FinOps. התוכנית כוללת הכנה לבחינת ההסמכה הבינלאומית AWS Practitioner. הקורס מתמקד בטכנולוגיות BI, SQL, Python, Tableau, ו-AWS, ומעניק לתלמידים כלים לפיתוח תובנות עסקיות, שליטה בעלויות ענן, וייעול ניצול השימוש בענן. התלמידים לומדים טכניקות מתקדמות כמו בניית Dashboards, שימוש ב-SSIS, וניתוח נתונים באמצעות Python. בנוסף, התוכנית כוללת סדנאות למיתוג אישי, כתיבת קורות חיים, והכנה לראיונות עבודה. התלמידים מקבלים ליווי אישי לאורך המסלול ובונים תיק עבודות להצגה למעסיקים. התוכנית נמשכת כ-6 חודשים, כוללת 200 שעות אקדמיות, ומתקיימת בקמפוס אוניברסיטת בר-אילן ברמת גן. בסיום התוכנית מוענקות שתי תעודות אוניברסיטאיות: אחת בתחום BI Developer והשנייה בתחום FinOps Specialist."
# }
# ```
#
# OpenAi Final Analysis Eng:
# ...
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\BI Fin Ops Sylabus.json
#
# =================================================================================
# Start Processing file: CC Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
# Certified in
# Cybersecurity
# (CC)
# :נושאי הקורס
# Security Principles
# Business Continuity (BC),
# Disaster Recovery (DR)
# & Incident Response
# Concepts
# Access Controls Concepts
# Network Security
# Security Operations
# 06.11.2024 :תאריך פתיחה
# בימים ראשון ורביעי
# 21:30 - 17:30 בין השעות
#  שעות אקדמיות)20(  מפגשים4 במשך
# הקורס היברידי: הלימודים יתקיימו בקמפוס
# אילן בר"ג ובזום, לבחירתכם -אוניברסיטת בר
# לאורך כל הקורס
#  בית הספר להייטק וסייבר של אוניברסיטת
# אילן, המהווה אקדמיה רשמית של -בר
#  בישראל, מזמין אתכם לקורס רקע ISC2
# והרחבת אופקים בעולמות הסייבר
# 052-5886002 :לתאום ראיון קבלה ורישום
# esther.asulin@biu.ac.il
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
# CC..
#
#
# 2
# ACADEMIC
# PARTNER
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: Certified in Cybersecurity (CC)\n\nCOURSE OVERVIEW: The Certified in Cybersecurity (CC) course is designed to provide foundational knowledge and expand horizons in the field of cybersecurity. This program is offered by the School of High-Tech and Cyber at Bar-Ilan University, which serves as an official ISC2 academy in Israel. The course aims to equip participants with essential cybersecurity principles and practices.\n\nCOURSE SCHEDULE: \n- Start Date: 06.11.2024.\n- Schedule: Sundays and Wednesdays, from 17:30 to 21:30.\n- Duration: 4 sessions, totaling 20 academic hours.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held at Bar-Ilan University campus in Ramat Gan and via Zoom, based on participants' preference.\n\nCOURSE TOPICS: \n- Security Principles.\n- Business Continuity (BC), Disaster Recovery (DR), and Incident Response Concepts.\n- Access Controls Concepts.\n- Network Security.\n- Security Operations.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact: \n  - Phone: 052-5886002.\n  - Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: The course is offered by the School of High-Tech and Cyber at Bar-Ilan University, which is an official ISC2 academy in Israel. The institution is dedicated to providing specialized programs in high-tech and cybersecurity fields."
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "Certified in Cybersecurity (CC)",
#     "instructors": [],
#     "summary": "The course 'Certified in Cybersecurity (CC)' covers essential topics in cybersecurity, including Security Principles, Business Continuity (BC), Disaster Recovery (DR), Incident Response Concepts, Access Controls Concepts, Network Security, and Security Operations. The course is hybrid, allowing participants to choose between in-person classes at Bar-Ilan University in Ramat Gan or online via Zoom. It spans 4 sessions, each lasting 5 hours (20 academic hours in total), held on Sundays and Wednesdays from 17:30 to 21:30. The course is offered by Bar-Ilan University's School of High-Tech and Cyber, an official ISC2 academy in Israel, providing foundational knowledge and insights into the field of cybersecurity. The start date for the course is November 6, 2024."
# }
# ```
#
# OpenAi Final Analysis Eng:
# {'course_name': 'Certified in Cybersecurity (CC)', 'instructors': [], 'summary': "The course 'Certified in Cybersecurity (CC)' covers essential topics in cybersecurity, including Security Principles, Business Continuity (BC), Disaster Recovery (DR), Incident Response Concepts, Access Controls Concepts, Network Security, and Security Operations. The course is hybrid, allowing participants to choose between in-person classes at Bar-Ilan University in Ramat Gan or online via Zoom. It spans 4 sessions, each lasting 5 hours (20 academic hours in total), held on Sundays and Wednesdays from 17:30 to 21:30. The course is offered by Bar-Ilan University's School of High-Tech and Cyber, an official ISC2 academy in Israel, providing foundational knowledge and insights into the field of cybersecurity. The start date for the course is November 6, 2024.", 'full_text': "COURSE NAME: Certified in Cybersecurity (CC)\n\nCOURSE OVERVIEW: The Certified in Cybersecurity (CC) course is designed to provide foundational knowledge and expand horizons in the field of cybersecurity. This program is offered by the School of High-Tech and Cyber at Bar-Ilan University, which serves as an official ISC2 academy in Israel. The course aims to equip participants with essential cybersecurity principles and practices.\n\nCOURSE SCHEDULE: \n- Start Date: 06.11.2024.\n- Schedule: Sundays and Wednesdays, from 17:30 to 21:30.\n- Duration: 4 sessions, totaling 20 academic hours.\n\nLEARNING FORMAT: \n- Hybrid learning format.\n- Classes will be held at Bar-Ilan University campus in Ramat Gan and via Zoom, based on participants' preference.\n\nCOURSE TOPICS: \n- Security Principles.\n- Business Continuity (BC), Disaster Recovery (DR), and Incident Response Concepts.\n- Access Controls Concepts.\n- Network Security.\n- Security Operations.\n\nREGISTRATION AND CONTACT INFORMATION: \n- To schedule an admission interview and register, contact: \n  - Phone: 052-5886002.\n  - Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION: The course is offered by the School of High-Tech and Cyber at Bar-Ilan University, which is an official ISC2 academy in Israel. The institution is dedicated to providing specialized programs in high-tech and cybersecurity fields.", 'full_text_no_tokens': 336}
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\CC Sylabus.json
#
# =================================================================================
# Start Processing file: CCNA Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
#  Cisco
#  Certified
#  Network
#  Associate
# CCNA
# •
# Explain the role and function of network
# components
# •
# Describe characteristics of network topology
# architectures
# •
# Compare physical interface and cabling types
# •
# Configure and verify IPv4 addressing and
# subnetting
# •
# Configure and verify IPv6 addressing and prefix
# •
# Describe wireless principles
# •
# Configure and verify VLANs (normal range)
# spanning multiple switches
# •
# Configure and verify interswitch connectivity
# •
# Configure and verify Layer 2 discovery protocols
# •
# Configure and verify (Layer 2/Layer 3)
# EtherChannel (LACP)
# •
# Describe AP and WLC management access
# connections
# •
# Interpret the components of routing table
# •
# Configure and verify IPv4 and IPv6 static routing
# •
# Configure and verify single area OSPFv2
# •
# Configure and verify inside source NAT using
# static and pools
# •
# Configure and verify NTP operating in a client and
# server mode
# •
# Configure and verify DHCP client and relay
# •
# Configure network devices for remote access
# using SSH
# •
# Define key security concepts (threats,
# vulnerabilities, exploits, and mitigation techniques)
# •
# Describe security program elements (user
# awareness, physical access control)
# •
# Configure device access control using local
# passwords
# •
# Describe security password policies elements
#   אשר מהווהCISCO זהו הקורס המקורי של
# CISCO IT Academy חלק מתוכנית
# בית הספר להייטק וסייבר
# אילן מזמין אתכם -של אוניברסיטת בר
# IT-לרכוש את ההסמכה המבוקשת  ב
# 052-5886002 :לתאום ראיון קבלה ורישום
# esther.asulin@biu.ac.il
# :נושאי הקורס
#  הקורס היברידי: הלימודים יתקיימו בקמפוס
# אילן בר״ג ובזום, לבחירתכם -אוניברסיטת בר
# לאורך כל הקורס
# 03.01.2025 :תאריך פתיחה
# 21:30-17:30 בימי שלישי בין השעות
# 13:00-09:00 בימי שישי בין השעות
#  שעות אקדמיות)85(  מפגשים17 במשך
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
# (cons)
#
#
#  LLM response_text1 ```json
# {
#   "full_text": "COURSE NAME: Cisco Certified Network Associate (CCNA)\n\nCOURSE OVERVIEW: This is the original Cisco course, part of the Cisco IT Academy program, offered by the School of High-Tech and Cyber at Bar-Ilan University. The course provides comprehensive training to achieve the sought-after IT certification in networking.\n\nCOURSE LEADERSHIP: Skip (No specific leadership details provided).\n\nPREREQUISITES: Skip (No prerequisites mentioned).\n\nCERTIFICATIONS: Cisco Certified Network Associate (CCNA).\n\nCOURSE SCHEDULE:\n- Start Date: 03.01.2025.\n- Duration: 17 sessions.\n- Academic Hours: 85 hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT:\n- Hybrid learning format.\n- Classes will be held on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on the participant's choice.\n\nTUITION AND FEES: Skip (No tuition or fee details provided).\n\nCOURSE TOPICS:\n- Explain the role and function of network components.\n- Describe characteristics of network topology architectures.\n- Compare physical interface and cabling types.\n- Configure and verify IPv4 addressing and subnetting.\n- Configure and verify IPv6 addressing and prefix.\n- Describe wireless principles.\n- Configure and verify VLANs (normal range) spanning multiple switches.\n- Configure and verify interswitch connectivity.\n- Configure and verify Layer 2 discovery protocols.\n- Configure and verify Layer 2/Layer 3 EtherChannel (LACP).\n- Describe AP and WLC management access connections.\n- Interpret the components of the routing table.\n- Configure and verify IPv4 and IPv6 static routing.\n- Configure and verify single area OSPFv2.\n- Configure and verify inside source NAT using static and pools.\n- Configure and verify NTP operating in a client and server mode.\n- Configure and verify DHCP client and relay.\n- Configure network devices for remote access using SSH.\n- Define key security concepts, including threats, vulnerabilities, exploits, and mitigation techniques.\n- Describe security program elements, such as user awareness and physical access control.\n- Configure device access control using local passwords.\n- Describe security password policy elements.\n\nREGISTRATION AND CONTACT INFORMATION:\n- To schedule an admission interview and registration, contact: 052-5886002.\n- Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION:\n- The course is part of the School of High-Tech and Cyber at Bar-Ilan University.\n- The program is offered by the dedicated programs division of Bar-Ilan University.\n"
# }
# ```
#
#  LLM response_text2 ```json
# {
#     "course_name": "Cisco Certified Network Associate (CCNA)",
#     "instructors": [],
#     "summary": "This course is the original Cisco course offered as part of the Cisco IT Academy program at Bar-Ilan University's School of High-Tech and Cyber. The course provides comprehensive training in networking concepts and practical skills, including configuring and verifying IPv4 and IPv6 addressing, VLANs, interswitch connectivity, Layer 2/Layer 3 EtherChannel, static routing, OSPFv2, NAT, NTP, DHCP, and SSH. It also covers network security concepts, password policies, and device access control. The hybrid course allows students to choose between in-person classes at Bar-Ilan University's Ramat Gan campus or online via Zoom. The course spans 17 sessions (85 academic hours) and begins on January 3, 2025, with classes held on Tuesdays (17:30-21:30) and Fridays (09:00-13:00)."
# }
# ```
#
# OpenAi Final Analysis Eng:
# {'course_name': 'Cisco Certified Network Associate (CCNA)', 'instructors': [], 'summary': "This course is the original Cisco course offered as part of the Cisco IT Academy program at Bar-Ilan University's School of High-Tech and Cyber. The course provides comprehensive training in networking concepts and practical skills, including configuring and verifying IPv4 and IPv6 addressing, VLANs, interswitch connectivity, Layer 2/Layer 3 EtherChannel, static routing, OSPFv2, NAT, NTP, DHCP, and SSH. It also covers network security concepts, password policies, and device access control. The hybrid course allows students to choose between in-person classes at Bar-Ilan University's Ramat Gan campus or online via Zoom. The course spans 17 sessions (85 academic hours) and begins on January 3, 2025, with classes held on Tuesdays (17:30-21:30) and Fridays (09:00-13:00).", 'full_text': "COURSE NAME: Cisco Certified Network Associate (CCNA)\n\nCOURSE OVERVIEW: This is the original Cisco course, part of the Cisco IT Academy program, offered by the School of High-Tech and Cyber at Bar-Ilan University. The course provides comprehensive training to achieve the sought-after IT certification in networking.\n\nCOURSE LEADERSHIP: Skip (No specific leadership details provided).\n\nPREREQUISITES: Skip (No prerequisites mentioned).\n\nCERTIFICATIONS: Cisco Certified Network Associate (CCNA).\n\nCOURSE SCHEDULE:\n- Start Date: 03.01.2025.\n- Duration: 17 sessions.\n- Academic Hours: 85 hours.\n- Schedule: Tuesdays from 17:30 to 21:30 and Fridays from 09:00 to 13:00.\n\nLEARNING FORMAT:\n- Hybrid learning format.\n- Classes will be held on-campus at Bar-Ilan University in Ramat Gan and via Zoom, based on the participant's choice.\n\nTUITION AND FEES: Skip (No tuition or fee details provided).\n\nCOURSE TOPICS:\n- Explain the role and function of network components.\n- Describe characteristics of network topology architectures.\n- Compare physical interface and cabling types.\n- Configure and verify IPv4 addressing and subnetting.\n- Configure and verify IPv6 addressing and prefix.\n- Describe wireless principles.\n- Configure and verify VLANs (normal range) spanning multiple switches.\n- Configure and verify interswitch connectivity.\n- Configure and verify Layer 2 discovery protocols.\n- Configure and verify Layer 2/Layer 3 EtherChannel (LACP).\n- Describe AP and WLC management access connections.\n- Interpret the components of the routing table.\n- Configure and verify IPv4 and IPv6 static routing.\n- Configure and verify single area OSPFv2.\n- Configure and verify inside source NAT using static and pools.\n- Configure and verify NTP operating in a client and server mode.\n- Configure and verify DHCP client and relay.\n- Configure network devices for remote access using SSH.\n- Define key security concepts, including threats, vulnerabilities, exploits, and mitigation techniques.\n- Describe security program elements, such as user awareness and physical access control.\n- Configure device access control using local passwords.\n- Describe security password policy elements.\n\nREGISTRATION AND CONTACT INFORMATION:\n- To schedule an admission interview and registration, contact: 052-5886002.\n- Email: esther.asulin@biu.ac.il.\n\nINSTITUTIONAL INFORMATION:\n- The course is part of the School of High-Tech and Cyber at Bar-Ilan University.\n- The program is offered by the dedicated programs division of Bar-Ilan University.\n", 'full_text_no_tokens': 597}
# Saved analysis to C:\github_repos\BIU_LLM_Project\data\documents\eng\CCNA Sylabus.json
#
# =================================================================================
# Start Processing file: CCSP Sylabus.pdf
#
#  Extracted text and images contetnt
#  b i u . a c . i l
# .משפיעים על המחר, היום
# Certified
# Cloud Security
# Professional
# (CCSP)
# :נושאי הקורס
# Cloud Concepts,
# Architecture and Design
# Cloud Data Security
# Cloud Platform and
# Infrastructure Security
# Cloud Application
# Security
# Cloud Security
# Operations
# Legal, Risk, and
# Compliance
# 17.02.2025 :תאריך פתיחה
# 21:30-17:30 בימי שני בין השעות
# 13:00-09:00 בימי שישי בין השעות
#  שעות אקדמיות)45(  מפגשים9 במשך
# הקורס היברידי: הלימודים יתקיימו בקמפוס
# אילן בר״ג ובזום, לבחירתכם -אוניברסיטת בר
# לאורך כל הקורס
#  שנות נסיון בטכנולוגיות המידע 5 :תנאי קדם
# ושיחה עם יועץ אקדמי
#  בית הספר להייטק וסייבר של אוניברסיטת
# אילן, המהווה אקדמיה רשמית של -בר
#  בישראל, מזמין אתכם להכשרה ISC2
# היוקרתית באבטחת הענן
# 052-5886002 :לתאום ראיון קבלה ורישום
# esther.asulin@biu.ac.il
#
#
#
#
#
#
# 2
# ACADEMIC
# PARTNER
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# בית הספר
#
# להייטק וסייבר
# המערךר לתוכניות ייעודיות
# אוניברסיטת בר-אילן
#
#
# CCSP.
